# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\ADMIN\\Downloads\\uber_rides_data_sample_train.csv")

# %%
df.shape
# Out:
# (200000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ride_id            200000 non-null  int64
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  object
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 12.2+ MB

# %%
df.columns
# Out:
# Index(['ride_id', 'fare_amount', 'pickup_datetime', 'pickup_longitude',
#        'pickup_latitude', 'dropoff_longitude', 'dropoff_latitude',
#        'passenger_count'],
#       dtype='object')

# %%
#How many missing values exists in 'dropoff_longitude' column?

# %%
len(df[(df["dropoff_longitude"].isna())])
# Out:
# 1

# %%
pd.to_datetime(df['pickup_datetime'])
# Out:
# 0        2015-05-07 19:52:06+00:00
# 1        2009-07-17 20:04:56+00:00
# 2        2009-08-24 21:45:00+00:00
# 3        2009-06-26 08:22:21+00:00
# 4        2014-08-28 17:47:00+00:00
#                     ...
# 199995   2012-10-28 10:49:00+00:00
# 199996   2014-03-14 01:09:00+00:00
# 199997   2009-06-29 00:42:00+00:00
# 199998   2015-05-20 14:56:25+00:00
# 199999   2010-05-15 04:08:00+00:00
# Name: pickup_datetime, Length: 200000, dtype: datetime64[ns, UTC]

# %%
pd.to_datetime(df['pickup_datetime'])
# Out:
# 0        2015-05-07 19:52:06+00:00
# 1        2009-07-17 20:04:56+00:00
# 2        2009-08-24 21:45:00+00:00
# 3        2009-06-26 08:22:21+00:00
# 4        2014-08-28 17:47:00+00:00
#                     ...
# 199995   2012-10-28 10:49:00+00:00
# 199996   2014-03-14 01:09:00+00:00
# 199997   2009-06-29 00:42:00+00:00
# 199998   2015-05-20 14:56:25+00:00
# 199999   2010-05-15 04:08:00+00:00
# Name: pickup_datetime, Length: 200000, dtype: datetime64[ns, UTC]

# %%
df.dropna()
df.describe()
# Out:
#             ride_id    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967153        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count
# count      199999.000000     199999.000000    200000.000000
# mean          -72.525292         39.923890         1.684535
# std            13.117408          6.794829         1.385997
# min         -3356.666300       -881.985513         0.000000
# ...

# %%
df.head(25)
# Out:
#      ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0   24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1   27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2   44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3   25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4   17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# 5   44470845          4.9 2011-02-12 02:27:09+00:00        -73.969019
# 6   48725865         24.5 2014-10-12 07:04:00+00:00        -73.961447
# 7   44195482          2.5 2012-12-11 13:52:00+00:00          0.000000
# 8   15822268          9.7 2012-02-17 09:32:00+00:00        -73.975187
# 9   50611056         12.5 2012-03-29 19:06:00+00:00        -74.001065
# 10   2205147          6.5 2015-05-22 17:32:27+00:00        -73.974388
# 11   6379048          8.5 2011-05-23 22:15:00+00:00          0.000000
# ...

# %%
df['pickup_datetime']=pd.to_datetime(df['pickup_datetime'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200000 entries, 0 to 199999
# Data columns (total 8 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ride_id            200000 non-null  int64
#  1   fare_amount        200000 non-null  float64
#  2   pickup_datetime    200000 non-null  datetime64[ns, UTC]
#  3   pickup_longitude   200000 non-null  float64
#  4   pickup_latitude    200000 non-null  float64
#  5   dropoff_longitude  199999 non-null  float64
#  6   dropoff_latitude   199999 non-null  float64
#  7   passenger_count    200000 non-null  int64
# dtypes: datetime64[ns, UTC](1), float64(5), int64(2)
# memory usage: 12.2 MB

# %%
#How many rides were recorded in the year 2014?

# %%
x=df['pickup_datetime'].dt.year
# Out:
# 0         2015
# 1         2009
# 2         2009
# 3         2009
# 4         2014
#           ...
# 199995    2012
# 199996    2014
# 199997    2009
# 199998    2015
# 199999    2010
# Name: pickup_datetime, Length: 200000, dtype: int32

# %%
x=pd.DatetimeIndex(df['pickup_datetime']).year

# %%
df.tail(15)
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 199985  25830754         24.0 2015-04-18 15:16:06+00:00        -74.005089
# 199986    236170         12.0 2013-09-07 09:54:32+00:00        -73.964772
# 199987  47043173          8.5 2011-04-30 00:09:16+00:00        -73.987260
# 199988  40002753          3.7 2011-10-09 02:02:40+00:00        -73.988674
# 199989  51736746          8.9 2010-02-18 07:12:00+00:00        -73.969152
# 199990   9577367         12.0 2015-05-24 22:05:56+00:00        -73.987106
# 199991  13512837         17.5 2015-06-08 10:49:14+00:00        -73.981453
# 199992  20566507          8.9 2010-01-30 16:24:00+00:00        -74.003548
# 199993  28359558          9.5 2012-09-29 19:51:27+00:00        -73.987798
# 199994   3189201         12.0 2014-01-31 14:42:00+00:00        -73.983070
# 199995  42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# ...

# %%
df.sort_values(by=['pickup_datetime'])
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 100844  55072468          8.5 2009-01-01 01:15:22+00:00        -73.981918
# 43961   30813112         13.0 2009-01-01 01:59:17+00:00        -73.983759
# 7628     8688426         10.6 2009-01-01 02:05:03+00:00        -73.956635
# 118760  13190369         12.2 2009-01-01 02:09:13+00:00        -73.984605
# 89763   45716268         11.0 2009-01-01 02:13:41+00:00        -73.980127
# ...          ...          ...                       ...               ...
# 2173    37789542         18.5 2015-06-30 22:57:53+00:00        -73.971703
# 80850   44430308         25.5 2015-06-30 23:16:42+00:00        -74.001099
# 56905   22269752         20.0 2015-06-30 23:31:06+00:00        -73.999962
# 32718   15173476          8.5 2015-06-30 23:33:33+00:00        -73.980988
# 162593  28165919         27.0 2015-06-30 23:40:39+00:00        -73.984795
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count
# ...

# %%
x=df[df['pickup_datetime'].dt.strftime('%Y') == '2014']

# %%
x['passenger_count'].count()
# Out:
# 29968

# %%
y=x[(x['pickup_datetime']>'2014-01-01')&(x['pickup_datetime']<'2014-04-01')]

# %%
y['passenger_count'].count()
# Out:
# 7687

# %%
#On which day of the week in September 2010, maximum rides were recorded ?

# %%
z=df[(df['pickup_datetime'].dt.strftime('%Y-%m')=='2010-09')]

# %%
z["acha"]=df['pickup_datetime'].dt.day
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7372\1132495419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z["acha"]=df['pickup_datetime'].dt.day

# %%
dw_mapping={
    0: 'Monday', 
    1: 'Tuesday', 
    2: 'Wednesday', 
    3: 'Thursday', 
    4: 'Friday',
    5: 'Saturday', 
    6: 'Sunday'
} 
z['day_of_week_name']=z['pickup_datetime'].dt.weekday.map(dw_mapping)
z
z['day_of_week_name']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7372\3292133762.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   z['day_of_week_name']=z['pickup_datetime'].dt.weekday.map(dw_mapping)
# 23         Saturday
# 85        Wednesday
# 87        Wednesday
# 126         Tuesday
# 129          Friday
#             ...
# 199584     Thursday
# 199665     Saturday
# 199851       Monday
# 199862     Thursday
# 199901    Wednesday
# Name: day_of_week_name, Length: 2482, dtype: object

# %%
z.head()
# Out:
#       ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 23   25121708          7.7 2010-09-04 16:12:00+00:00        -73.994300
# 85   11536406          7.7 2010-09-08 10:16:01+00:00        -73.987383
# 87   11267091          4.5 2010-09-22 12:15:00+00:00        -73.981920
# 126   8791172          5.3 2010-09-21 12:38:00+00:00        -73.956158
# 129  30203807         10.5 2010-09-10 16:28:00+00:00        -73.995627
#
#      pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# 23         40.739512         -73.988070         40.724482                2
# 85         40.721255         -73.954733         40.730683                1
# 87         40.761172         -74.016152         40.704765                1
# 126        40.781593         -73.966138         40.773645                1
# 129        40.749295         -73.965087         40.771610                1
#
#      acha day_of_week_name
# 23      4         Saturday
# 85      8        Wednesday
# ...

# %%
y=z['day_of_week_name']=="Sunday"
print("Sunday",y.sum())
y=z['day_of_week_name']=="Monday"
print("Monday",y.sum())
y=z['day_of_week_name']=="Tuesday"
print("Tuesday",y.sum())
y=z['day_of_week_name']=="Wednesday"
print("Wednesday",y.sum())
y=z['day_of_week_name']=="Thursday"
print("Thrusday",y.sum())
y=z['day_of_week_name']=="Friday"
print("Friday",y.sum())
y=z['day_of_week_name']=="Saturday"
print("Saturday",y.sum())
# Out:
# Sunday 331
# Monday 265
# Tuesday 322
# Wednesday 391
# Thrusday 457
# Friday 354
# Saturday 362

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 6371  # Earth radius in kilometers

    lat1, lon1, lat2, lon2 = map(np.radians, [lat1, lon1, lat2, lon2])

    dlat = lat2 - lat1
    dlon = lon2 - lon1

    a = np.sin(dlat/2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon/2)**2
    c = 2 * np.arcsin(np.sqrt(a))

    distance = R * c
    return distance

# %%
 df['distance'] = df.apply(lambda row: haversine(row['pickup_latitude'], row['pickup_longitude'], row['dropoff_latitude'], row['dropoff_longitude']), axis=1)

# %%
df
# Out:
#          ride_id  fare_amount           pickup_datetime  pickup_longitude  \
# 0       24238194          7.5 2015-05-07 19:52:06+00:00        -73.999817
# 1       27835199          7.7 2009-07-17 20:04:56+00:00        -73.994355
# 2       44984355         12.9 2009-08-24 21:45:00+00:00        -74.005043
# 3       25894730          5.3 2009-06-26 08:22:21+00:00        -73.976124
# 4       17610152         16.0 2014-08-28 17:47:00+00:00        -73.925023
# ...          ...          ...                       ...               ...
# 199995  42598914          3.0 2012-10-28 10:49:00+00:00        -73.987042
# 199996  16382965          7.5 2014-03-14 01:09:00+00:00        -73.984722
# 199997  27804658         30.9 2009-06-29 00:42:00+00:00        -73.986017
# 199998  20259894         14.5 2015-05-20 14:56:25+00:00        -73.997124
# 199999  11951496         14.1 2010-05-15 04:08:00+00:00        -73.984395
#
#         pickup_latitude  dropoff_longitude  dropoff_latitude  passenger_count  \
# ...

# %% [markdown]
# df.describe()

# %%
df.describe()
# Out:
#             ride_id    fare_amount  pickup_longitude  pickup_latitude  \
# count  2.000000e+05  200000.000000     200000.000000    200000.000000
# mean   2.771250e+07      11.359955        -72.527638        39.935885
# std    1.601382e+07       9.901776         11.437787         7.720539
# min    1.000000e+00     -52.000000      -1340.648410       -74.015515
# 25%    1.382535e+07       6.000000        -73.992065        40.734796
# 50%    2.774550e+07       8.500000        -73.981823        40.752592
# 75%    4.155530e+07      12.500000        -73.967153        40.767158
# max    5.542357e+07     499.000000         57.418457      1644.421482
#
#        dropoff_longitude  dropoff_latitude  passenger_count       distance
# count      199999.000000     199999.000000    200000.000000  199999.000000
# mean          -72.525292         39.923890         1.684535      20.855350
# std            13.117408          6.794829         1.385997     382.964642
# ...

# %%
zero_distance  = df[df['distance'] == 0.0]
mean = zero_distance['fare_amount'].mean()
print(mean)
# Out:
# 11.585317826704546

# %%
a=df['fare_amount'].max()
# Out:
# 499.0

# %%
df.loc[df["fare_amount"]==499,["distance"]]
# Out:
#         distance
# 170081   0.00079

# %%
zero_dist=df.loc[df["distance"]==0.0]

# %%
zero_dist["passenger_count"].count()
# Out:
# 5632
